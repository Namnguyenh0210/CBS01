# %%
import pandas as pd

# %%
import pandas as pd

rf = pd.read_csv("Billionaires.csv")
pd.set_option("display.max_columns", None)  # Hiển thị tất cả các cột
pd.set_option("display.float_format", "{:,.2f}".format)  # Định dạng số có dấu phân cách
display(rf)  # Hiển thị 10 dòng đầu tiên
# Out:
#       Rank                      Name Net Worth   Age Country | Territory  \
# 0        1  Bernard Arnault & family    $211 B 74.00              France
# 1        2                 Elon Musk    $180 B 51.00       United States
# 2        3                Jeff Bezos    $114 B 59.00       United States
# 3        4             Larry Ellison    $107 B 78.00       United States
# 4        5            Warren Buffett    $106 B 92.00       United States
# ...    ...                       ...       ...   ...                 ...
# 2635  2540                   Yu Rong      $1 B 51.00               China
# 2636  2540    Richard Yuengling, Jr.      $1 B 80.00       United States
# 2637  2540             Zhang Gongyun      $1 B 60.00               China
# 2638  2540    Zhang Guiping & family      $1 B 71.00               China
# 2639  2540               Inigo Zobel      $1 B 66.00         Philippines
#
#                             Source               Industry
# ...

# %% [markdown]
# ### Lây 5 người đầu tiên và lọc ra chỉ lấy tên với tiền

# %%
rf_new =rf.drop(['Age','Country | Territory','Source','Industry'], axis=1, inplace=True)
print(rf.head(5))
# Out:
#    Rank                      Name Net Worth
# 0     1  Bernard Arnault & family    $211 B
# 1     2                 Elon Musk    $180 B
# 2     3                Jeff Bezos    $114 B
# 3     4             Larry Ellison    $107 B
# 4     5            Warren Buffett    $106 B

# %%
import pandas as pd

# Đọc dữ liệu
pd.read_csv("cars-sale.csv")
# Xem thông tin tổng quan về dữ liệu
df.info()

# Xử lý dữ liệu thiếu
df.dropna(inplace=True)

# Chuyển đổi giá từ chuỗi sang số
df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)

# Tính toán xe có giá bán đắt nhất
most_expensive_car = df.loc[df['Price'].idxmax()]
print("Xe bán đắt nhất:", most_expensive_car)

# Tính toán giá trên mỗi km đã đi
df['Price_per_km'] = df['Price'] / df['Odometer']
cheapest_per_km = df.loc[df['Price_per_km'].idxmin()]
print("Hãng xe có giá trên mỗi km đi rẻ nhất:", cheapest_per_km['Make'])

# Tính giá trung bình theo hãng
avg_price_by_make = df.groupby('Make')['Price'].mean()
most_expensive_make = avg_price_by_make.idxmax()
print("Hãng xe có giá bán trung bình cao nhất:", most_expensive_make)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Đọc dữ liệu
# ----> 4 pd.read_csv("cars-sale.csv")
#       5 # Xem thông tin tổng quan về dữ liệu
#       6 df.info()
#
# ...
